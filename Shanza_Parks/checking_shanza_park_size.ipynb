# %%
import geopandas as gpd
import numpy as np

# %%
parks = gpd.read_file('dallas_parks_reccenters.gpkg')

# %%
parks.head()
# Out:
#               NAME    CITY    source  OBJECTID ADDRESS  MAINTDIST  Type  \
# 0   Cotillion Park  Dallas  centroid       NaN    None        NaN  None
# 1    Weichsel Park  Dallas  centroid       NaN    None        NaN  None
# 2  Cherrywood Park  Dallas  centroid       NaN    None        NaN  None
# 3     Glencoe Park  Dallas  centroid       NaN    None        NaN  None
# 4      Tietze Park  Dallas  centroid       NaN    None        NaN  None
#
#   Service_Ar                    geometry
# 0       None  POINT (-96.65529 32.84466)
# 1       None  POINT (-96.83486 32.82674)
# 2       None  POINT (-96.82837 32.82306)
# 3       None   POINT (-96.77838 32.8327)
# 4       None  POINT (-96.76083 32.82346)

# %%
len(parks)
# Out:
# 427
