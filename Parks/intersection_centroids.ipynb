# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
import shapely # map-rendering library
import numpy as np
import fiona # enging for reading more robust data files
import contextily as cx

# %%
grid_intersect = gpd.read_file("../Parks/grid_intersect.geojson")
grid_intersect = grid_intersect.to_crs("EPSG:4326")
grid_intersect["centroid"] = grid_intersect.centroid
# Out:
# /tmp/ipykernel_3200497/1277922052.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   grid_intersect["centroid"] = grid_intersect.centroid

# %%
grid_intersect_centroids = grid_intersect[["NAME", "OWNER", "NOTES", "CITY", "FEATTYPE", "centroid"]]
grid_intersect_centroids.head()
grid_intersect_centroids.to_file("grid_intersect_centroids.shp")
# Out:
# (3527, 6)

# %%
#dallas_county_parks[dallas_county_parks["OBJECTID"] == 1048].iloc[0].geometry.boundary#.coords.xy
# delauney triangulation in shapely
# grid, idea
# boundary points
